# %% [markdown]
# ![Screen%20Shot%202020-05-20%20at%209.webp](attachment:Screen%20Shot%202020-05-20%20at%209.webp)

# %% [markdown]
# ###### First of all We have need to import all required Libarary's.

# %%
import pandas as pd 
import numpy as np 

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ###### Now we have import our Customer_retention_case study_datasets.

# %%
df_1= pd.read_excel(r"G:\Intershop_21\FlipRobo Project\4 Assignment\Customer_retention_dataset_1\Customer_retention_dataset\customer_retention_dataset.xlsx", sheet_name=1)
df_2= pd.read_excel(r"G:\Intershop_21\FlipRobo Project\4 Assignment\Customer_retention_dataset_1\Customer_retention_dataset\customer_retention_dataset.xlsx", sheet_name=0)

# %%
df_1
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
df_1.head()     # Checking the first five rows of the data.
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
df_1.tail()     # Checking the last five rows of the data.
# Out:
#      1Gender of respondent  2 How old are you?   \
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#      5 Since How Long You are Shopping Online ?  \
# ...

# %%
df_1.sample(10)     # Checking the random ten rows of the data.
# Out:
#      1Gender of respondent  2 How old are you?   \
# 1                        1                    2
# 117                      0                    3
# 155                      1                    5
# 70                       1                    2
# 265                      1                    3
# 241                      1                    5
# 197                      0                    5
# 233                      1                    2
# 11                       1                    4
# 7                        0                    4
#
#     3 Which city do you shop online from?  \
# 1                                   Delhi
# 117                                 Noida
# 155                              Gurgaon
# 70                             Bangalore
# 265                             Ghaziabad
# 241                              Gurgaon
# 197                                 Noida
# 233                            Bangalore
# 11                                  Noida
# ...

# %%
df_1.shape        # Checking shape of the data.
# Out:
# (269, 71)

# %% [markdown]
# #### Our Data is having 269 rows and 71 columns.
# #### The header for each column is a question asked to customers as feedback.
# #### We will change this question into some meaningful variable name.

# %%
df_1.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %% [markdown]
# #### In the above output, we can see all the 71 questions asked to online customers.
# #### Some questions are personal questions, some questions are related to website and brand, in the end, questions are related to the recommendation and related to the online store.

# %%
Dictionary={'1Gender of respondent':'Gender', '2 How old are you? ':'Age',
       '3 Which city do you shop online from?':'City',
       '4 What is the Pin Code of where you shop online from?':'PinCode',
       '5 Since How Long You are Shopping Online ?': 'Years_of_shoping',
       '6 How many times you have made an online purchase in the past 1 year?':'No_Online_purchage_last_Year',
       '7 How do you access the internet while shopping on-line?':'Internet_Access',
       '8 Which device do you use to access the online shopping?':'Device_Used',
       '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ':'Screen_size',
       '10 What is the operating system (OS) of your device?\t\t\t\t                                          ':'Operating_system',
       '11 What browser do you run on your device to access the website?\t\t\t                                                          ':'Browser_Name',
       '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ':'Channel_Used',
       '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ':'Reach_after_first_visit',
       '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ':'Decision_Time',
       '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ':'Preferred_Payment_mode',
       '16 How 4 do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ':'Abondon_shoping',
       '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ':'Abondon_Reason',
       '18 The content on the website must be easy to read and understand':'Website_content_easeness',
       '19 Information on similar product to the one highlighted  is important for product comparison':'Information_for_Comparision',
       '20 Complete information on listed seller and product being offered is important for purchase decision.':'SellerProduct_info',
       '21 All relevant information on listed products must be stated clearly':'Clear_information',
       '22 Ease of navigation in website':'Ease_of_navigation', '23 Loading and processing speed':'Loading_processing_speed',
       '24 User friendly Interface of the website':'UserFriendly_Interface',
       '25 Convenient Payment methods':'Convenient_pay_mode',
       '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time':'Trust',
       '27 Empathy (readiness to assist with queries) towards the customers':'Empathy_to_customer',
       '28 Being able to guarantee the privacy of the customer':'Privacy_of_customers',
       '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)':'Comm_channels_Responsiveness',
       '30 Online shopping gives monetary benefit and discounts':'Monetry_benefits_and_discounts',
       '31 Enjoyment is derived from shopping online':'Enjoyement',
       '32 Shopping online is convenient and flexible':'Convenient_and_Flexible',
       '33 Return and replacement policy of the e-tailer is important for purchase decision':'Retirn_policy',
       '34 Gaining access to loyalty programs is a benefit of shopping online':'Loyality_program',
       '35 Displaying quality Information on the website improves satisfaction of customers':'Quality_info_on_web',
       '36 User derive satisfaction while shopping on a good quality website or application':'Satisfaction_due_to_good_quality_website',
       '37 Net Benefit derived from shopping online can lead to users satisfaction':'Net_benefits',
       '38 User satisfaction cannot exist without trust':'Satisfaction_Trust',
       '39 Offering a wide variety of listed product in several category':'Wide_variety',
       '40 Provision of complete and relevant product information':'Complete_Relevent_info',
       '41 Monetary savings':'Monetary_savings',
       '42 The Convenience of patronizing the online retailer':'Convenience_of_patronizing',
       '43 Shopping on the website gives you the sense of adventure':'Sense_of_advanture',
       '44 Shopping on your preferred e-tailer enhances your social status':'Social_status',
       '45 You feel gratification shopping on your favorite e-tailer':'gratification',
       '46 Shopping on the website helps you fulfill certain roles':'Help_fullfill_roles',
       '47 Getting value for money spent':'Value_of_money',
       'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ':'Online_retailer',
       'Easy to use website or application':'Easy_use_webapp',
       'Visual appealing web-page layout':'Visual_appealing', 'Wild variety of product on offer':'Wild_variety',
       'Complete, relevant description information of products':'Informtion_of_product',
       'Fast loading website speed of website and application':'Fast_loading_webApp',
       'Reliability of the website or application':'Reliability',
       'Quickness to complete purchase':'Quickness_purpchase',
       'Availability of several payment options':'Payment_option', 'Speedy order delivery ':'Speedy_delivery',
       'Privacy of customers’ information':'Info_Privacy',
       'Security of customer financial information':'Fincial_info_security',
       'Perceived Trustworthiness':'Perceived_Trustworthiness',
       'Presence of online assistance through multi-channel':'Online_assistance',
       'Longer time to get logged in (promotion, sales period)':'Longer_logged_in',
       'Longer time in displaying graphics and photos (promotion, sales period)':'Longer_display_time',
       'Late declaration of price (promotion, sales period)':'Late_price_declaration',
       'Longer page loading time (promotion, sales period)':'Longer_page_loading',
       'Limited mode of payment on most products (promotion, sales period)':'Limited_payment_mode',
       'Longer delivery period':'Long_delivary_period', 'Change in website/Application design':'Change_in_website',
       'Frequent disruption when moving from one page to another':'Frequent_disruption',
       'Website is as efficient as before':'Efficient_website',
       'Which of the Indian online retailer would you recommend to a friend?':'Recommended_retailers'}

# %%
df_1.rename(columns=Dictionary, inplace=True)

# %%
df_2.rename(columns=Dictionary, inplace=True)

# %%
df_1
# Out:
#      Gender  Age           City  PinCode  Years_of_shoping  \
# 0         0    3          Delhi   110009                 5
# 1         1    2          Delhi   110030                 5
# 2         1    2  Greater Noida   201308                 4
# 3         0    2        Karnal    132001                 4
# 4         1    2     Bangalore    530068                 3
# ..      ...  ...            ...      ...               ...
# 264       1    2          Solan   173212                 2
# 265       1    3      Ghaziabad   201008                 2
# 266       1    4     Bangalore    560010                 3
# 267       1    1          Solan   173229                 3
# 268       1    4      Ghaziabad   201009                 3
#
#      No_Online_purchage_last_Year  Internet_Access  Device_Used  Screen_size  \
# 0                               4                4            3            5
# 1                               5                2            1            2
# ...

# %%
df_1.isnull().sum()
# Out:
# Gender                   0
# Age                      0
# City                     0
# PinCode                  0
# Years_of_shoping         0
#                         ..
# Long_delivary_period     0
# Change_in_website        0
# Frequent_disruption      0
# Efficient_website        0
# Recommended_retailers    0
# Length: 71, dtype: int64

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Gender                                    269 non-null    int64
#  1   Age                                       269 non-null    int64
#  2   City                                      269 non-null    object
#  3   PinCode                                   269 non-null    int64
#  4   Years_of_shoping                          269 non-null    int64
#  5   No_Online_purchage_last_Year              269 non-null    int64
#  6   Internet_Access                           269 non-null    int64
#  7   Device_Used                               269 non-null    int64
#  8   Screen_size                               269 non-null    int64
#  9   Operating_system                          269 non-null    int64
# ...

# %% [markdown]
# # Data analtysis and Visualization

# %% [markdown]
# ##### In Further Data analtysis and visualization parts we will be asking some problem question and try to visulize and find out using python codes.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Gender'])
plt.xlabel('Gender', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Gender', fontsize=20)

plt.subplot(1,2,2)

df_2['Gender'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Gender', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Gender', fontsize=20)

print(df_2['Gender'].value_counts())
print(df_2['Gender'].value_counts()/269*100)
# Out:
# Female    181
# Male       88
# Name: Gender, dtype: int64
# Female    67.286245
# Male      32.713755
# Name: Gender, dtype: float64

# %% [markdown]
# From graphs we can see 67.29 percent online customers are females and 32.71 percent are Males.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Age'])
plt.xlabel('Age', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Age', fontsize=20)

plt.subplot(1,2,2)

df_2['Age'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Age', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Age', fontsize=20)

print(df_2['Age'].value_counts())
print(df_2['Age'].value_counts()/269*100)
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: Age, dtype: int64
# 31-40 years           30.111524
# 21-30 years           29.368030
# 41-50 yaers           26.022305
# Less than 20 years     7.434944
# 51 years and above     7.063197
# Name: Age, dtype: float64

# %% [markdown]
# Here we can see Maximum online shoppers are from age group 31-40 Years.
# More than 75 percent of online shoppers are lies between 21-50 years old.
# Numbers for less than 20 years and above 51 are less, which indicates thease age group rarely use online shoping.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['City'])
plt.xlabel('City', fontsize=16,)
plt.ylabel('Count', fontsize=16)
plt.title('City', fontsize=20)

plt.subplot(1,2,2)

df_2['City'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('City', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('City', fontsize=20)

print(df_2['City'].value_counts())
print(df_2['City'].value_counts()/269*100)
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: City, dtype: int64
# Delhi            21.561338
# Greater Noida    15.985130
# Noida            14.869888
# Bangalore        13.754647
# Karnal           10.037175
# Solan             6.691450
# Ghaziabad         6.691450
# Gurgaon           4.460967
# Merrut            3.345725
# Moradabad         1.858736
# Bulandshahr       0.743494
# Name: City, dtype: float64

# %% [markdown]
# Here we can see Delhi Having Highest Number of customers who shope online.
# Graph also showing that most of the customers are from Delhi, Greater Noida, Noida, Banglore and Karnal.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Years_of_shoping'])
plt.xlabel('Years_of_shoping', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Years_of_shoping', fontsize=20)

plt.subplot(1,2,2)

df_2['Years_of_shoping'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Years_of_shoping', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Years_of_shoping', fontsize=20)

print(df_2['Years_of_shoping'].value_counts())
print(df_2['Years_of_shoping'].value_counts()/269*100)
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: Years_of_shoping, dtype: int64
# Above 4 years       36.431227
# 2-3 years           24.163569
# 3-4 years           17.472119
# Less than 1 year    15.985130
# 1-2 years            5.947955
# Name: Years_of_shoping, dtype: float64

# %% [markdown]
# Here we see the 36.43 percent of online shoppers are using online shopings for more than 4 years.
# Customers with 1-2 years of shoping experince are less.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['No_Online_purchage_last_Year'])
plt.xlabel('No_Online_purchage_last_Year', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('No_Online_purchage_last_Year', fontsize=20)

plt.subplot(1,2,2)

df_2['No_Online_purchage_last_Year'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('No_Online_purchage_last_Year', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('No_Online_purchage_last_Year', fontsize=20)

print(df_2['No_Online_purchage_last_Year'].value_counts())
print(df_2['No_Online_purchage_last_Year'].value_counts()/269*100)
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: No_Online_purchage_last_Year, dtype: int64
# Less than 10 times    42.379182
# 31-40 times           23.420074
# 41 times and above    17.472119
# 11-20 times           10.780669
# 21-30 times            3.717472
# 42 times and above     2.230483
# Name: No_Online_purchage_last_Year, dtype: float64

# %% [markdown]
# Here we see the Majority of the online shopers shop less than 10 times in a year.
# Shopers shoping more than 31 time in a year also good in numbers.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Internet_Access'])
plt.xlabel('Internet_Access', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Internet_Access', fontsize=20)
plt.grid()

plt.subplot(1,2,2)

df_2['Internet_Access'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Internet_Access', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Internet_Access', fontsize=20)

print(df_2['Internet_Access'].value_counts())
print(df_2['Internet_Access'].value_counts()/269*100)
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: Internet_Access, dtype: int64
# Mobile internet    52.788104
# Wi-Fi              28.252788
# Mobile Internet    17.472119
# Dial-up             1.486989
# Name: Internet_Access, dtype: float64

# %% [markdown]
# Here we can see two Type of values for Mobile Internet, which is basicaly due to typing error, We need to make it as one type of value

# %%
df_2.replace(to_replace='Mobile internet', value='Mobile Internet', inplace=True)

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Internet_Access'])
plt.xlabel('Internet_Access', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Internet_Access', fontsize=20)
plt.grid()

plt.subplot(1,2,2)

df_2['Internet_Access'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Internet_Access', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Internet_Access', fontsize=20)

print(df_2['Internet_Access'].value_counts())
print(df_2['Internet_Access'].value_counts()/269*100)
# Out:
# Mobile Internet    189
# Wi-Fi               76
# Dial-up              4
# Name: Internet_Access, dtype: int64
# Mobile Internet    70.260223
# Wi-Fi              28.252788
# Dial-up             1.486989
# Name: Internet_Access, dtype: float64

# %% [markdown]
# Majority of the shoppers are using Mobile internet for shoping online.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Device_Used'])
plt.xlabel('Device_Used', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Device_Used', fontsize=20)
plt.grid()

plt.subplot(1,2,2)

df_2['Device_Used'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Device_Used', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Device_Used', fontsize=20)

print(df_2['Device_Used'].value_counts())
print(df_2['Device_Used'].value_counts()/269*100)
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: Device_Used, dtype: int64
# Smartphone    52.416357
# Laptop        31.970260
# Desktop       11.152416
# Tablet         4.460967
# Name: Device_Used, dtype: float64

# %% [markdown]
# More than 52 percent online shoppers are using Smartphones for online purcahse.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Screen_size'])
plt.xlabel('Screen_size', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Screen_size', fontsize=20)

plt.subplot(1,2,2)

df_2['Screen_size'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Screen_size', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Screen_size', fontsize=20)

print(df_2['Screen_size'].value_counts())
print(df_2['Screen_size'].value_counts()/269*100)
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: Screen_size, dtype: int64
# Others        49.814126
# 5.5 inches    36.802974
# 4.7 inches    10.780669
# 5 inches       2.602230
# Name: Screen_size, dtype: float64

# %% [markdown]
# Majority of the shoppers Screen size data is not available

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Operating_system'])
plt.xlabel('Operating_system', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Operating_system', fontsize=20)
plt.grid()

plt.subplot(1,2,2)

df_2['Operating_system'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Operating_system', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Operating_system', fontsize=20)

print(df_2['Operating_system'].value_counts())
print(df_2['Operating_system'].value_counts()/269*100)
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: Operating_system, dtype: int64
# Window/windows Mobile    45.353160
# Android                  31.598513
# IOS/Mac                  23.048327
# Name: Operating_system, dtype: float64

# %% [markdown]
# Most of the cutomres are using Windows OS.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Browser_Name'])
plt.xlabel('Browser_NameBrowser_Name', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Browser_Name', fontsize=20)

plt.subplot(1,2,2)

df_2['Browser_Name'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Browser_Name', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Browser_Name', fontsize=20)

print(df_2['Browser_Name'].value_counts())
print(df_2['Browser_Name'].value_counts()/269*100)
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: Browser_Name, dtype: int64
# Google chrome      80.297398
# Safari             14.869888
# Opera               2.973978
# Mozilla Firefox     1.858736
# Name: Browser_Name, dtype: float64

# %% [markdown]
# From Graphs we can see Mostly users are using Google Chrome for Browsing.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Channel_Used'])
plt.xlabel('Channel_Used', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Channel_Used', fontsize=20)

plt.subplot(1,2,2)

df_2['Channel_Used'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Channel_Used', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Channel_Used', fontsize=20)

print(df_2['Channel_Used'].value_counts())
print(df_2['Channel_Used'].value_counts()/269*100)
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: Channel_Used, dtype: int64
# Search Engine        85.501859
# Content Marketing     7.434944
# Display Adverts       7.063197
# Name: Channel_Used, dtype: float64

# %% [markdown]
# Graphs Indicates that majority of the custometers are using Search engine for the first time to arive at online store.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Reach_after_first_visit'])
plt.xlabel('Reach_after_first_visit', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Reach_after_first_visit', fontsize=20)

plt.subplot(1,2,2)

df_2['Reach_after_first_visit'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Reach_after_first_visit', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Reach_after_first_visit', fontsize=20)

print(df_2['Reach_after_first_visit'].value_counts())
print(df_2['Reach_after_first_visit'].value_counts()/269*100)
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: Reach_after_first_visit, dtype: int64
# Search Engine      32.342007
# Via application    31.970260
# Direct URL         26.022305
# E-mail              6.691450
# Social Media        2.973978
# Name: Reach_after_first_visit, dtype: float64

# %% [markdown]
# Majority of the users are using Search Engine and Application after first Visit.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Decision_Time'])
plt.xlabel('Decision_Time', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Decision_Time', fontsize=20)

plt.subplot(1,2,2)

df_2['Decision_Time'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Decision_Time', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Decision_Time', fontsize=20)

print(df_2['Decision_Time'].value_counts())
print(df_2['Decision_Time'].value_counts()/269*100)
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: Decision_Time, dtype: int64
# more than 15 mins    45.724907
# 6-10 mins            26.394052
# 11-15 mins           17.100372
# Less than 1 min       5.576208
# 1-5 mins              5.204461
# Name: Decision_Time, dtype: float64

# %% [markdown]
# We can see mostly custmors take more than 15 min to make descision for purchase.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Preferred_Payment_mode'])
plt.xlabel('Preferred_Payment_mode', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Preferred_Payment_mode', fontsize=20)

plt.subplot(1,2,2)

df_2['Preferred_Payment_mode'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Preferred_Payment_mode', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Preferred_Payment_mode', fontsize=20)

print(df_2['Preferred_Payment_mode'].value_counts())
print(df_2['Preferred_Payment_mode'].value_counts()/269*100)
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: Preferred_Payment_mode, dtype: int64
# Credit/Debit cards                    55.018587
# Cash on delivery (CoD)                28.252788
# E-wallets (Paytm, Freecharge etc.)    16.728625
# Name: Preferred_Payment_mode, dtype: float64

# %% [markdown]
# Most of the shoppers are use Credit/Debit card for making payments.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_1['Abondon_shoping'])
plt.xlabel('Abondon_shoping', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Abondon_shoping', fontsize=20)

plt.subplot(1,2,2)

df_1['Abondon_shoping'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Abondon_shoping', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Abondon_shoping', fontsize=20)

print(df_1['Abondon_shoping'].value_counts())
print(df_1['Abondon_shoping'].value_counts()/269*100)
# Out:
# 3    171
# 1     48
# 4     35
# 5     15
# Name: Abondon_shoping, dtype: int64
# 3    63.568773
# 1    17.843866
# 4    13.011152
# 5     5.576208
# Name: Abondon_shoping, dtype: float64

# %% [markdown]
# Here 3 is maximum which Indicates "sometime", User abondon shoping

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Abondon_Reason'])
plt.xlabel('Abondon_Reason', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Abondon_Reason', fontsize=20)

plt.subplot(1,2,2)

df_2['Abondon_Reason'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Abondon_Reason', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Abondon_Reason', fontsize=20)

print(df_2['Abondon_Reason'].value_counts())
print(df_2['Abondon_Reason'].value_counts()/269*100)
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: Abondon_Reason, dtype: int64
# Better alternative offer        49.442379
# Promo code not applicable       20.074349
# Change in price                 13.754647
# Lack of trust                   11.524164
# No preferred mode of payment     5.204461
# Name: Abondon_Reason, dtype: float64

# %% [markdown]
# Majorty of the shoppers abondon because they are having Better Alternative offer.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Website_content_easeness'])
plt.xlabel('Website_content_easeness', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Website_content_easeness', fontsize=20)

plt.subplot(1,2,2)

df_2['Website_content_easeness'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Website_content_easeness', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Website_content_easeness', fontsize=20)

print(df_2['Website_content_easeness'].value_counts())
print(df_2['Website_content_easeness'].value_counts()/269*100)
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: Website_content_easeness, dtype: int64
# Strongly agree (5)       60.966543
# Agree (4)                29.739777
# Strongly disagree (1)     6.691450
# Indifferent (3)           2.602230
# Name: Website_content_easeness, dtype: float64

# %% [markdown]
# More than 60 percent online shoppers Strongly agree that content on website should be easy to understand.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Information_for_Comparision'])
plt.xlabel('Information_for_Comparision', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Information_for_Comparision', fontsize=20)

plt.subplot(1,2,2)

df_2['Information_for_Comparision'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Information_for_Comparision', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Information_for_Comparision', fontsize=20)

print(df_2['Information_for_Comparision'].value_counts())
print(df_2['Information_for_Comparision'].value_counts()/269*100)
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: Information_for_Comparision, dtype: int64
# Strongly agree (5)    43.122677
# Agree (4)             34.200743
# Indifferent (3)       15.985130
# Dis-agree (2)          6.691450
# Name: Information_for_Comparision, dtype: float64

# %% [markdown]
# Majority of the online shoppers are agree that highlighted information on similer product is important for comparision.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['SellerProduct_info'])
plt.xlabel('SellerProduct_infoSellerProduct_info', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('SellerProduct_info', fontsize=20)

plt.subplot(1,2,2)

df_2['SellerProduct_info'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('SellerProduct_info', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('SellerProduct_info', fontsize=20)

print(df_2['SellerProduct_info'].value_counts())
print(df_2['SellerProduct_info'].value_counts()/269*100)
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: SellerProduct_info, dtype: int64
# Agree (4)                37.546468
# Strongly agree (5)       32.342007
# Indifferent (3)          19.330855
# Dis-agree (2)             6.691450
# Strongly disagree (1)     4.089219
# Name: SellerProduct_info, dtype: float64

# %% [markdown]
# Majority of the shoppers agree that having seller information and product being offerd by them, helps in making buying decision.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Clear_information'])
plt.xlabel('Clear_information', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Clear_information', fontsize=20)

plt.subplot(1,2,2)

df_2['Clear_information'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Clear_information', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Clear_information', fontsize=20)

print(df_2['Clear_information'].value_counts())
print(df_2['Clear_information'].value_counts()/269*100)
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: Clear_information, dtype: int64
# Agree (4)                49.070632
# Strongly agree (5)       39.776952
# Strongly disagree (1)     6.691450
# Dis-agree (2)             4.460967
# Name: Clear_information, dtype: float64

# %% [markdown]
# Majority of the shoppers are agree on having clear product information increase chance of buying.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Ease_of_navigation'])
plt.xlabel('Ease_of_navigation', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Ease_of_navigation', fontsize=20)

plt.subplot(1,2,2)

df_2['Ease_of_navigation'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Ease_of_navigation', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Ease_of_navigation', fontsize=20)

print(df_2['Ease_of_navigation'].value_counts())
print(df_2['Ease_of_navigation'].value_counts()/269*100)
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: Ease_of_navigation, dtype: int64
# Strongly agree (5)       52.416357
# Agree (4)                39.033457
# Strongly disagree (1)     6.691450
# Dis-agree (2)             1.858736
# Name: Ease_of_navigation, dtype: float64

# %% [markdown]
# More than 80 percent shoppers who participated in survey agree, that navigation should be easy.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Loading_processing_speed'])
plt.xlabel('Loading_processing_speed', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Loading_processing_speed', fontsize=20)

plt.subplot(1,2,2)

df_2['Loading_processing_speed'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Loading_processing_speed', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Loading_processing_speed', fontsize=20)

print(df_2['Loading_processing_speed'].value_counts())
print(df_2['Loading_processing_speed'].value_counts()/269*100)
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Indifferent (3)           12
# Strongly disagree (1)     12
# Name: Loading_processing_speed, dtype: int64
# Strongly agree (5)       42.750929
# Agree (4)                41.635688
# Dis-agree (2)             6.691450
# Indifferent (3)           4.460967
# Strongly disagree (1)     4.460967
# Name: Loading_processing_speed, dtype: float64

# %% [markdown]
# Majority of shoppers are strogly agree that loading and processing speed affect in buying decision.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['UserFriendly_Interface'])
plt.xlabel('UserFriendly_Interface', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('UserFriendly_Interface', fontsize=20)

plt.subplot(1,2,2)

df_2['UserFriendly_Interface'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('UserFriendly_Interface', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('UserFriendly_Interface', fontsize=20)

print(df_2['UserFriendly_Interface'].value_counts())
print(df_2['UserFriendly_Interface'].value_counts()/269*100)
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: UserFriendly_Interface, dtype: int64
# Strongly agree (5)       70.260223
# Agree (4)                16.728625
# Strongly disagree (1)     6.691450
# Dis-agree (2)             4.460967
# Indifferent (3)           1.858736
# Name: UserFriendly_Interface, dtype: float64

# %% [markdown]
# Majority of the online shoppers are strongly agree that having User Friendly interface affect the buying decision.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Convenient_pay_mode'])
plt.xlabel('Convenient_pay_mode', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Convenient_pay_mode', fontsize=20)

plt.subplot(1,2,2)

df_2['Convenient_pay_mode'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Convenient_pay_modeConvenient_pay_mode', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Convenient_pay_mode', fontsize=20)

print(df_2['Convenient_pay_mode'].value_counts())
print(df_2['Convenient_pay_mode'].value_counts()/269*100)
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: Convenient_pay_mode, dtype: int64
# Strongly agree (5)    59.107807
# Agree (4)             29.739777
# Dis-agree (2)         11.152416
# Name: Convenient_pay_mode, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree that having conveniet pay mode affect the Buying decision.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Trust'])
plt.xlabel('Trust', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Trust', fontsize=20)

plt.subplot(1,2,2)

df_2['Trust'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Trust', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Trust', fontsize=20)

print(df_2['Trust'].value_counts())
print(df_2['Trust'].value_counts()/269*100)
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: Trust, dtype: int64
# Strongly agree (5)    52.416357
# Agree (4)             31.970260
# Disagree (2)          11.152416
# indifferent  (3)       4.460967
# Name: Trust, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree to have trust for transaction, for making buying decision

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Empathy_to_customer'])
plt.xlabel('Empathy_to_customer', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Empathy_to_customer', fontsize=20)

plt.subplot(1,2,2)

df_2['Empathy_to_customer'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Empathy_to_customer', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Empathy_to_customer', fontsize=20)

print(df_2['Empathy_to_customer'].value_counts())
print(df_2['Empathy_to_customer'].value_counts()/269*100)
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: Empathy_to_customer, dtype: int64
# Strongly agree (5)       72.118959
# Agree (4)                15.613383
# Strongly disagree (1)     6.691450
# indifferent (3)           5.576208
# Name: Empathy_to_customer, dtype: float64

# %% [markdown]
# Majority of the shoppers are agree that having empathy to customers, affect the chance of buying

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Privacy_of_customers'])
plt.xlabel('Privacy_of_customers', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Privacy_of_customers', fontsize=20)

plt.subplot(1,2,2)

df_2['Privacy_of_customers'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Privacy_of_customers', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Privacy_of_customers', fontsize=20)

print(df_2['Privacy_of_customers'].value_counts())
print(df_2['Privacy_of_customers'].value_counts()/269*100)
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: Privacy_of_customers, dtype: int64
# Strongly agree (5)    68.773234
# Agree (4)             21.561338
# indifferent (3)        9.665428
# Name: Privacy_of_customers, dtype: float64

# %% [markdown]
# Graphs showing privicy play important role in making buying descisions, majority of the shoppers are strongly agree.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Comm_channels_Responsiveness'])
plt.xlabel('Comm_channels_Responsiveness', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Comm_channels_Responsiveness', fontsize=20)

plt.subplot(1,2,2)

df_2['Comm_channels_Responsiveness'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Comm_channels_Responsiveness', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Comm_channels_Responsiveness', fontsize=20)

print(df_2['Comm_channels_Responsiveness'].value_counts())
print(df_2['Comm_channels_Responsiveness'].value_counts()/269*100)
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: Comm_channels_Responsiveness, dtype: int64
# Strongly agree (5)       55.390335
# Agree (4)                34.944238
# indifferent (3)           5.576208
# Strongly disagree (1)     4.089219
# Name: Comm_channels_Responsiveness, dtype: float64

# %% [markdown]
# Majority of the shoppers are agree that having Responsiveness Communication channels, affect the chance of buying.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Monetry_benefits_and_discounts'])
plt.xlabel('Monetry_benefits_and_discounts', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Monetry_benefits_and_discounts', fontsize=20)

plt.subplot(1,2,2)

df_2['Monetry_benefits_and_discounts'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Monetry_benefits_and_discounts', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Monetry_benefits_and_discounts', fontsize=20)

print(df_2['Monetry_benefits_and_discounts'].value_counts())
print(df_2['Monetry_benefits_and_discounts'].value_counts()/269*100)
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: Monetry_benefits_and_discounts, dtype: int64
# Strongly agree (5)       39.033457
# Agree (4)                31.598513
# indifferent (3)          18.587361
# Strongly disagree (1)     6.691450
# Dis-agree (2)             4.089219
# Name: Monetry_benefits_and_discounts, dtype: float64

# %% [markdown]
# Majority of the shoppers are agree that online shoping gives Monetry Benefits and disconts.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Enjoyement'])
plt.xlabel('Enjoyement', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Enjoyement', fontsize=20)

plt.subplot(1,2,2)

df_2['Enjoyement'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Enjoyement', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Enjoyement', fontsize=20)

print(df_2['Enjoyement'].value_counts())
print(df_2['Enjoyement'].value_counts()/269*100)
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: Enjoyement, dtype: int64
# Strongly agree (5)       31.970260
# indifferent (3)          27.881041
# Agree (4)                21.933086
# Strongly disagree (1)    11.152416
# Dis-agree (2)             7.063197
# Name: Enjoyement, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree to have enjoyment from online shoping online

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Convenient_and_Flexible'])
plt.xlabel('Convenient_and_Flexible', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Convenient_and_Flexible', fontsize=20)

plt.subplot(1,2,2)

df_2['Convenient_and_Flexible'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Convenient_and_Flexible', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Convenient_and_Flexible', fontsize=20)

print(df_2['Convenient_and_Flexible'].value_counts())
print(df_2['Convenient_and_Flexible'].value_counts()/269*100)
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: Convenient_and_Flexible, dtype: int64
# Strongly agree (5)    54.275093
# Agree (4)             28.996283
# indifferent (3)       12.267658
# Dis-agree (2)          4.460967
# Name: Convenient_and_Flexible, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree that shoping online is Convenient and Flexible.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Retirn_policy'])
plt.xlabel('Retirn_policy', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Retirn_policy', fontsize=20)

plt.subplot(1,2,2)

df_2['Retirn_policy'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Retirn_policy', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Retirn_policy', fontsize=20)

print(df_2['Retirn_policy'].value_counts())
print(df_2['Retirn_policy'].value_counts()/269*100)
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: Retirn_policy, dtype: int64
# Strongly agree (5)    73.605948
# Agree (4)             18.959108
# Dis-agree (2)          7.434944
# Name: Retirn_policy, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree that Return policy affect the buying decison.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Loyality_program'])
plt.xlabel('Loyality_program', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Loyality_program', fontsize=20)

plt.subplot(1,2,2)

df_2['Loyality_program'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Loyality_program', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Loyality_program', fontsize=20)

print(df_2['Loyality_program'].value_counts())
print(df_2['Loyality_program'].value_counts()/269*100)
# Out:
# Strongly agree (5)       115
# indifferent (3)           64
# Agree (4)                 64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: Loyality_program, dtype: int64
# Strongly agree (5)       42.750929
# indifferent (3)          23.791822
# Agree (4)                23.791822
# Dis-agree (2)             5.576208
# Strongly disagree (1)     4.089219
# Name: Loyality_program, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree that Gaining access to loyalty programs is a benefit of shopping online.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Quality_info_on_web'])
plt.xlabel('Quality_info_on_web', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Quality_info_on_web', fontsize=20)

plt.subplot(1,2,2)

df_2['Quality_info_on_web'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Quality_info_on_web', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Quality_info_on_web', fontsize=20)

print(df_2['Quality_info_on_web'].value_counts())
print(df_2['Quality_info_on_web'].value_counts()/269*100)
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: Quality_info_on_web, dtype: int64
# Strongly agree (5)    49.442379
# Agree (4)             29.739777
# indifferent (3)       20.817844
# Name: Quality_info_on_web, dtype: float64

# %% [markdown]
# Majority of shoppers are strongly agree Displaying quality Information on the website improves satisfaction of customers.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Satisfaction_due_to_good_quality_website'])
plt.xlabel('Satisfaction_due_to_good_quality_website', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Satisfaction_due_to_good_quality_website', fontsize=20)

plt.subplot(1,2,2)

df_2['Satisfaction_due_to_good_quality_website'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Satisfaction_due_to_good_quality_website', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Satisfaction_due_to_good_quality_website', fontsize=20)

print(df_2['Satisfaction_due_to_good_quality_website'].value_counts())
print(df_2['Satisfaction_due_to_good_quality_website'].value_counts()/269*100)
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: Satisfaction_due_to_good_quality_website, dtype: int64
# Strongly agree (5)    65.055762
# Agree (4)             31.970260
# Dis-agree (2)          2.973978
# Name: Satisfaction_due_to_good_quality_website, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree User derive satisfaction while shopping on a good quality website or application.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Net_benefits'])
plt.xlabel('Net_benefits', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Net_benefits', fontsize=20)

plt.subplot(1,2,2)

df_2['Net_benefits'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Net_benefits', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Net_benefits', fontsize=20)

print(df_2['Net_benefits'].value_counts())
print(df_2['Net_benefits'].value_counts()/269*100)
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: Net_benefits, dtype: int64
# Strongly agree (5)    60.966543
# Agree (4)             20.074349
# indifferent (3)       14.869888
# Dis-agree (2)          4.089219
# Name: Net_benefits, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree that Net Benefit derived from shopping online can lead to users satisfaction.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Satisfaction_Trust'])
plt.xlabel('Satisfaction_Trust', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Satisfaction_Trust', fontsize=20)

plt.subplot(1,2,2)

df_2['Satisfaction_Trust'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Satisfaction_Trust', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Satisfaction_Trust', fontsize=20)

print(df_2['Satisfaction_Trust'].value_counts())
print(df_2['Satisfaction_Trust'].value_counts()/269*100)
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: Satisfaction_Trust, dtype: int64
# Strongly agree (5)       45.353160
# Agree (4)                43.494424
# Strongly disagree (1)     6.691450
# Dis-agree (2)             2.602230
# indifferent (3)           1.858736
# Name: Satisfaction_Trust, dtype: float64

# %% [markdown]
# Majority of the shoppers strogly agree that User satisfaction cannot exist without trust.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Wide_variety'])
plt.xlabel('Wide_variety', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Wide_variety', fontsize=20)

plt.subplot(1,2,2)

df_2['Wide_variety'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Wide_variety', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Wide_variety', fontsize=20)

print(df_2['Wide_variety'].value_counts())
print(df_2['Wide_variety'].value_counts()/269*100)
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: Wide_variety, dtype: int64
# Strongly agree (5)    41.263941
# Agree (4)             34.944238
# indifferent (3)       21.189591
# Dis-agree (2)          2.602230
# Name: Wide_variety, dtype: float64

# %% [markdown]
# Majority of the shoppers are agree that online shoping Offering a wide variety of listed product in several category.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Complete_Relevent_info'])
plt.xlabel('Complete_Relevent_info', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Complete_Relevent_info', fontsize=20)

plt.subplot(1,2,2)

df_2['Complete_Relevent_info'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Complete_Relevent_info', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Complete_Relevent_info', fontsize=20)

print(df_2['Complete_Relevent_info'].value_counts())
print(df_2['Complete_Relevent_info'].value_counts()/269*100)
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: Complete_Relevent_info, dtype: int64
# Strongly agree (5)    50.185874
# Agree (4)             36.431227
# indifferent (3)       11.524164
# Disagree (2)           1.858736
# Name: Complete_Relevent_info, dtype: float64

# %% [markdown]
# Majority of the shoppers are strongly agree that having complete and relevant product information increase chance of buying.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Monetary_savings'])
plt.xlabel('Monetary_savings', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Monetary_savings', fontsize=20)

plt.subplot(1,2,2)

df_2['Monetary_savings'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Monetary_savings', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Monetary_savings', fontsize=20)

print(df_2['Monetary_savings'].value_counts())
print(df_2['Monetary_savings'].value_counts()/269*100)
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: Monetary_savings, dtype: int64
# Strongly agree (5)    55.018587
# Agree (4)             27.881041
# Disagree (2)          11.524164
# indifferent (3)        5.576208
# Name: Monetary_savings, dtype: float64

# %% [markdown]
# Majority of the shoppers strongly agree that online shoping provide monetary savings.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Convenience_of_patronizing'])
plt.xlabel('Convenience_of_patronizing', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Convenience_of_patronizing', fontsize=20)

plt.subplot(1,2,2)

df_2['Convenience_of_patronizing'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Convenience_of_patronizing', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Convenience_of_patronizing', fontsize=20)

print(df_2['Convenience_of_patronizing'].value_counts())
print(df_2['Convenience_of_patronizing'].value_counts()/269*100)
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: Convenience_of_patronizing, dtype: int64
# Agree (4)             51.301115
# indifferent (3)       28.624535
# Strongly agree (5)    20.074349
# Name: Convenience_of_patronizing, dtype: float64

# %% [markdown]
# Majority of the shoppers are agree, There is Convenience of patronizing the online retailer.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Sense_of_advanture'])
plt.xlabel('Sense_of_advanture', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Sense_of_advanture', fontsize=20)

plt.subplot(1,2,2)

df_2['Sense_of_advanture'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Sense_of_advanture', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Sense_of_advanture', fontsize=20)

print(df_2['Sense_of_advanture'].value_counts())
print(df_2['Sense_of_advanture'].value_counts()/269*100)
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: Sense_of_advanture, dtype: int64
# Agree (4)                37.546468
# indifferent (3)          21.933086
# Strongly agree (5)       20.074349
# Dis-agree (2)            18.587361
# Strongly disagree (1)     1.858736
# Name: Sense_of_advanture, dtype: float64

# %% [markdown]
# Majority of the shoppers are agree that Shopping on the website gives you the sense of adventure.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Social_status'])
plt.xlabel('Social_status', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Social_status', fontsize=20)

plt.subplot(1,2,2)

df_2['Social_status'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Social_status', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Social_status', fontsize=20)

print(df_2['Social_status'].value_counts())
print(df_2['Social_status'].value_counts()/269*100)
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: Social_status, dtype: int64
# indifferent (3)          37.174721
# Agree (4)                21.933086
# Strongly agree (5)       17.843866
# Strongly disagree (1)    12.267658
# Dis-agree (2)            10.780669
# Name: Social_status, dtype: float64

# %% [markdown]
# Majority of the online shoppers are having Indiffrent views for Shopping on your preferred e-tailer enhances your social status.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['gratification'])
plt.xlabel('gratification', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('gratification', fontsize=20)

plt.subplot(1,2,2)

df_2['gratification'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('gratification', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('gratification', fontsize=20)

print(df_2['gratification'].value_counts())
print(df_2['gratification'].value_counts()/269*100)
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: gratification, dtype: int64
# indifferent (3)          37.546468
# Strongly agree (5)       24.163569
# Agree (4)                23.420074
# Disagree (2)              8.178439
# Strongly disagree (1)     6.691450
# Name: gratification, dtype: float64

# %% [markdown]
# Shoppers having Indiffrent view for feel gratification shopping on your favorite e-tailer.

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Help_fullfill_roles'])
plt.xlabel('Help_fullfill_roles', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Help_fullfill_roles', fontsize=20)

plt.subplot(1,2,2)

df_2['Help_fullfill_roles'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Help_fullfill_roles', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Help_fullfill_roles', fontsize=20)

print(df_2['Help_fullfill_roles'].value_counts())
print(df_2['Help_fullfill_roles'].value_counts()/269*100)
# Out:
# indifferent (3)          88
# Agree (4)                88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: Help_fullfill_roles, dtype: int64
# indifferent (3)          32.713755
# Agree (4)                32.713755
# Strongly agree (5)       14.126394
# Strongly disagree (1)    12.267658
# Dis-agree (2)             8.178439
# Name: Help_fullfill_roles, dtype: float64

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)

sns.countplot(df_2['Value_of_money'])
plt.xlabel('Value_of_money', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Value_of_money', fontsize=20)

plt.subplot(1,2,2)

df_2['Value_of_money'].value_counts().plot(kind="pie",autopct='%.2f%%',shadow=True,fontsize=14)
plt.xlabel('Value_of_money', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Value_of_money', fontsize=20)

print(df_2['Value_of_money'].value_counts())
print(df_2['Value_of_money'].value_counts()/269*100)
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: Value_of_money, dtype: int64
# Agree (4)             55.390335
# Strongly agree (5)    30.483271
# indifferent (3)       14.126394
# Name: Value_of_money, dtype: float64

# %% [markdown]
# Majority of the shoppers are agree to have value of money.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Online_retailer'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Online_retailer', fontsize=16)
plt.title('Online_retailer', fontsize=20)
plt.grid()

# %% [markdown]
# Majority of the shoppers are using multiple retailers for shoping online.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Easy_use_webapp'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Easy_use_webapp', fontsize=16)
plt.title('Easy_use_webapp', fontsize=20)
plt.grid()

# %% [markdown]
# Majority of website and applications are easy to use.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Visual_appealing'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Visual_appealing', fontsize=16)
plt.title('Visual_appealing', fontsize=20)
plt.grid()

# %% [markdown]
# Accordig Majority of shoppers Amazon and Flipkart having good visual appealing.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Wild_variety'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Wild_variety', fontsize=16)
plt.title('Wild_variety', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon and Flipkart are having wild variety of prodcts on offer.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Informtion_of_product'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Informtion_of_product', fontsize=16)
plt.title('Informtion_of_product', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon and Flipkart having Complete, relevant description information of products.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Fast_loading_webApp'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Fast_loading_webApp', fontsize=16)
plt.title('Fast_loading_webApp', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon, Flipkart and Paytm having fastest loading website and application.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Reliability'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Reliability', fontsize=16)
plt.title('Reliability', fontsize=20)
plt.grid()

# %% [markdown]
# According to majority of the shopers amazon is more Reliabil website or application.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Quickness_purpchase'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Quickness_purpchase', fontsize=16)
plt.title('Quickness_purpchase', fontsize=20)
plt.grid()

# %% [markdown]
# According to majority of the shoppers amazon is having Quickness to complete purchase.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Payment_option'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Payment_option', fontsize=16)
plt.title('Payment_option', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon and Flipkart are having Availability of several payment options.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Speedy_delivery'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Speedy_delivery', fontsize=16)
plt.title('Speedy_delivery', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon provide Speedy order delivery.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Info_Privacy'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Info_Privacy', fontsize=16)
plt.title('Info_Privacy', fontsize=20)
plt.grid()

# %% [markdown]
# Majority of the shoppers recommend Amazon as best retails for provideing mPrivacy of customers’ information.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Fincial_info_security'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Fincial_info_security', fontsize=16)
plt.title('Fincial_info_security', fontsize=20)
plt.grid()

# %% [markdown]
# Majority of retails provide Security of customer financial information

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Perceived_Trustworthiness'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Perceived_Trustworthiness', fontsize=16)
plt.title('Perceived_Trustworthiness', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon is more Perceived_Trustworthiness than other retailers

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Online_assistance'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Online_assistance', fontsize=16)
plt.title('Online_assistance', fontsize=20)
plt.grid()

# %% [markdown]
# Majority of the retailers provide online assitance through multiple channels.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Longer_logged_in'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Longer_logged_in', fontsize=16)
plt.title('Longer_logged_in', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon have Longer time to get logged in (promotion, sales period).

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Longer_display_time'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Longer_display_time', fontsize=16)
plt.title('Longer_display_time', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon and flipcart take Longer time in displaying graphics and photos (promotion, sales period).

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Late_price_declaration'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Late_price_declaration', fontsize=16)
plt.title('Late_price_declaration', fontsize=20)
plt.grid()

# %% [markdown]
# According to Majority of the shoper Myntra having Late declaration of price (promotion, sales period).

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Longer_page_loading'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Longer_page_loading', fontsize=16)
plt.title('Longer_page_loading', fontsize=20)
plt.grid()

# %% [markdown]
# According to Majority of the shoper Myntra having longer page loading time, paytm is at 2nd place.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Limited_payment_mode'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Limited_payment_mode', fontsize=16)
plt.title('Limited_payment_mode', fontsize=20)
plt.grid()

# %% [markdown]
# According to Majority of the shoper Snapdeal having Limited_payment_mode.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Long_delivary_period'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Long_delivary_period', fontsize=16)
plt.title('Long_delivary_period', fontsize=20)
plt.grid()

# %% [markdown]
# According to Majority of the shoper Paytm having Long_delffvary_period.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Change_in_website'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Change_in_website', fontsize=16)
plt.title('Change_in_website', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon having Change_in_website according to requirements of user.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Frequent_disruption'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Frequent_disruption', fontsize=16)
plt.title('Frequent_disruption', fontsize=20)
plt.grid()

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Efficient_website'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Efficient_website', fontsize=16)
plt.title('Efficient_website', fontsize=20)
plt.grid()

# %% [markdown]
# According to majority of shoppers Amazon.in is Efficient website.

# %%
plt.figure(figsize=(10,8))
sns.countplot(y=df_2['Recommended_retailers'])
plt.xlabel('Count', fontsize=16)
plt.ylabel('Recommended_retailers', fontsize=16)
plt.title('Recommended_retailers', fontsize=20)
plt.grid()

# %% [markdown]
# Amazon and Flipcart are most recomended retailers.

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Age', hue='Gender', data=df_2)
plt.xlabel('Age', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Age & Gender')
plt.grid()

# %% [markdown]
# Here we can see Maximum shoppers in every age group are females.
# 21-30 Age group is more active in online purcahse.
# Age group 21- 50 years are activily puchaning online as compare to age less than 20 and 51 years above.

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='City', hue='Gender', data=df_2)
plt.xlabel('City', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('City & Gender')
plt.grid()

# %% [markdown]
# Here we can see in most of the cities Female buyers are more as compare to male.
# Only Delhi and noida having maximum male buyer as compare to females.
# In cities like Moradabad and buladshar we have only male buyers.
# In merrut and Solan we have only female buyers.

# %%
plt.figure(figsize=(16,7))
sns.countplot(x='Decision_Time', hue='Gender', data=df_2)
plt.xlabel('Decision_Time', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('Decision_Time & Gender')
# Out:
# Text(0.5, 1.0, 'Decision_Time & Gender')

# %% [markdown]
# Here Graph showing relation exploration time before making buying decision and Internet access with respect to gender.
# We can see Girls taking more exploration time befor making buying decision,

# %%
plt.figure(figsize=(12,8))
sns.countplot(y='Recommended_retailers', hue='Gender', data=df_2)
plt.xlabel('Count', fontsize=16)
plt.ylabel('Recommended_retailers', fontsize=16)
plt.title('Recommended_retailers',fontsize=20)
plt.grid()

# %% [markdown]
# Here we can see majoity of male and females are having Amozon as First choise and Flipcart is the second choice of the shoppers.
